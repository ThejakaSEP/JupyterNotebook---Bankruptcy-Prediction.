# %%
pip install numpy pandas sklearn

# %%
import numpy as np
import pandas as pd

#For plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#setting the option to display all the columns in the kernel
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',7000)

#Importing the dataset to a data frame in Pandas
df = pd.read_csv('/Users/thejakamahaulpatha/PycharmProjects/Bankruptcy Prediction with Jupyter Notebook/Dataset/data.csv')

# %% [markdown]
# # Basic EDA ( Exploratory Data Analysis) with Descriptive Statistics

# %%
#How many rows and columns?
df.shape
# Out:
# (6819, 96)

# %%
#What do the data look like
df.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
#Checking the bottom 5 rows
df.tail()
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 6814                                 0.539468
# 6815                                 0.538269
# 6816                                 0.533744
# 6817                                 0.559911
# 6818                                 0.570105
#
#        ROA(B) before interest and depreciation after tax  \
# 6814                                           0.543230
# 6815                                           0.524172
# 6816                                           0.520638
# ...

# %%
#Understand the data types in of the columns
df.dtypes
# Out:
# Bankrupt?                                                     int64
#  ROA(C) before interest and depreciation before interest    float64
#  ROA(A) before interest and % after tax                     float64
#  ROA(B) before interest and depreciation after tax          float64
#  Operating Gross Margin                                     float64
#  Realized Sales Gross Margin                                float64
#  Operating Profit Rate                                      float64
#  Pre-tax net Interest Rate                                  float64
#  After-tax net Interest Rate                                float64
#  Non-industry income and expenditure/revenue                float64
#  Continuous interest rate (after tax)                       float64
#  Operating Expense Rate                                     float64
#  Research and development expense rate                      float64
#  Cash flow rate                                             float64
# ...

# %%
#Checking the basic descriptive stats
df.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# ...

# %% [markdown]
# # Basic EDA with plotting

# %%
# 1. Histograms

numbers = pd.Series(df.columns)
df[numbers].hist(figsize = (40, 40))
plt.show();

# %%
# 2. Boxplots
df.plot(kind = 'box', subplots = True, layout = (25, 4), sharex = False, sharey = False, figsize = (40, 200));
